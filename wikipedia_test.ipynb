# %%
# Out:
# {'1979 Islamic Revolution': 1979 Islamic Revolution (id: ??, ns: 0),
#  '2009 Iranian presidential election': 2009 Iranian presidential election (id: ??, ns: 0),
#  'ASPCA': ASPCA (id: ??, ns: 0),
#  'Acrostic': Acrostic (id: ??, ns: 0),
#  'Actinomorphic': Actinomorphic (id: ??, ns: 0),
#  'Afghanistan': Afghanistan (id: ??, ns: 0),
#  'Ahmet III': Ahmet III (id: ??, ns: 0),
#  'Al-Andalus': Al-Andalus (id: ??, ns: 0),
#  'Albania': Albania (id: ??, ns: 0),
#  'Alexander Marshal': Alexander Marshal (id: ??, ns: 0),
#  'Alexandre Dumas, père': Alexandre Dumas, père (id: ??, ns: 0),
#  'Alexandria': Alexandria (id: ??, ns: 0),
#  'Alfred Daniel Hall': Alfred Daniel Hall (id: ??, ns: 0),
#  'Allah': Allah (id: ??, ns: 0),
#  'Allergen': Allergen (id: ??, ns: 0),
#  'Allergy': Allergy (id: ??, ns: 0),
#  'Amana (plant)': Amana (plant) (id: ??, ns: 0),
#  'Ambassador': Ambassador (id: ??, ns: 0),
#  'Amsterdam': Amsterdam (id: ??, ns: 0),
#  'Anatolia': Anatolia (id: ??, ns: 0),
#  'Androecium': Androecium (id: ??, ns: 0),
#  'Anemone': Anemone (id: ??, ns: 0),
#  'Anna Pavord': Anna Pavord (id: ??, ns: 0),
#  'Anthocyanin': Anthocyanin (id: ??, ns: 0),
#  'Anthracnose': Anthracnose (id: ??, ns: 0),
#  'Antwerp': Antwerp (id: ??, ns: 0),
#  'Asexual reproduction': Asexual reproduction (id: ??, ns: 0),
#  'Augsburg': Augsburg (id: ??, ns: 0),
#  'Australian Plant Name Index': Australian Plant Name Index (id: ??, ns: 0),
#  'Ayatollah Ruhollah Khomeini': Ayatollah Ruhollah Khomeini (id: ??, ns: 0),
#  'Azaz': Azaz (id: ??, ns: 0),
#  'Azerbaijan': Azerbaijan (id: ??, ns: 0),
#  'Babur': Babur (id: ??, ns: 0),
#  'Baburnama': Baburnama (id: ??, ns: 0),
#  'Bacterial soft rot': Bacterial soft rot (id: ??, ns: 0),
#  'Baku': Baku (id: ??, ns: 0),
#  'Balkans': Balkans (id: ??, ns: 0),
#  'Battle of Karbala': Battle of Karbala (id: ??, ns: 0),
#  'Ben Zonneveld': Ben Zonneveld (id: ??, ns: 0),
#  'Billboard': Billboard (id: ??, ns: 0),
#  'Biodiversity': Biodiversity (id: ??, ns: 0),
#  'Blackland, Wiltshire': Blackland, Wiltshire (id: ??, ns: 0),
#  'Blight': Blight (id: ??, ns: 0),
#  'Bloomsbury Publishing': Bloomsbury Publishing (id: ??, ns: 0),
#  'Blue mold': Blue mold (id: ??, ns: 0),
#  'Botanical Journal of the Linnean Society': Botanical Journal of the Linnean Society (id: ??, ns: 0),
#  'Botryotinia': Botryotinia (id: ??, ns: 0),
#  'Bukhara': Bukhara (id: ??, ns: 0),
#  'Bulb': Bulb (id: ??, ns: 0),
#  'Bulbs': Bulbs (id: ??, ns: 0),
#  'Bulgaria': Bulgaria (id: ??, ns: 0),
#  'Caducous': Caducous (id: ??, ns: 0),
#  'Calne': Calne (id: ??, ns: 0),
#  'Calochortoideae': Calochortoideae (id: ??, ns: 0),
#  'Calochortus': Calochortus (id: ??, ns: 0),
#  'Calvinism': Calvinism (id: ??, ns: 0),
#  'Cambridge University Press': Cambridge University Press (id: ??, ns: 0),
#  'Canadian Tulip Festival': Canadian Tulip Festival (id: ??, ns: 0),
#  'Capsule (fruit)': Capsule (fruit) (id: ??, ns: 0),
#  'Cardiocrinum': Cardiocrinum (id: ??, ns: 0),
#  'Carl Linnaeus': Carl Linnaeus (id: ??, ns: 0),
#  'Carolus Clusius': Carolus Clusius (id: ??, ns: 0),
#  'Caspian Sea': Caspian Sea (id: ??, ns: 0),
#  'Catalogue of Life': Catalogue of Life (id: ??, ns: 0),
#  'Central Asia': Central Asia (id: ??, ns: 0),
#  'Centre of diversity': Centre of diversity (id: ??, ns: 0),
#  'Ceramic': Ceramic (id: ??, ns: 0),
#  'Chagatai people': Chagatai people (id: ??, ns: 0),
#  'Chaparral': Chaparral (id: ??, ns: 0),
#  'Clintonia': Clintonia (id: ??, ns: 0),
#  'Cloning': Cloning (id: ??, ns: 0),
#  'Coin': Coin (id: ??, ns: 0),
#  'Coneflower': Coneflower (id: ??, ns: 0),
#  'Conrad Gessner': Conrad Gessner (id: ??, ns: 0),
#  'Crescent': Crescent (id: ??, ns: 0),
#  'Crimea': Crimea (id: ??, ns: 0),
#  'Cross-pollination': Cross-pollination (id: ??, ns: 0),
#  'Cultivar': Cultivar (id: ??, ns: 0),
#  "Curtis's Botanical Magazine": Curtis's Botanical Magazine (id: ??, ns: 0),
#  'Cut flowers': Cut flowers (id: ??, ns: 0),
#  'Dallas': Dallas (id: ??, ns: 0),
#  'Decomposition': Decomposition (id: ??, ns: 0),
#  'Delphinidin': Delphinidin (id: ??, ns: 0),
#  'Derek Fell': Derek Fell (id: ??, ns: 0),
#  'Dermatitis': Dermatitis (id: ??, ns: 0),
#  'Doi (identifier)': Doi (identifier) (id: ??, ns: 0),
#  'Dutch Golden Age painting': Dutch Golden Age painting (id: ??, ns: 0),
#  'Dutch famine of 1944–45': Dutch famine of 1944–45 (id: ??, ns: 0),
#  'EPPO Code': EPPO Code (id: ??, ns: 0),
#  'East India Company': East India Company (id: ??, ns: 0),
#  'Easter': Easter (id: ??, ns: 0),
#  'Edinburgh University Press': Edinburgh University Press (id: ??, ns: 0),
#  'Ellipsoid': Ellipsoid (id: ??, ns: 0),
#  'Encyclopedia of Life': Encyclopedia of Life (id: ??, ns: 0),
#  'Endosperm': Endosperm (id: ??, ns: 0),
#  'England': England (id: ??, ns: 0),
#  'Erythronium': Erythronium (id: ??, ns: 0),
#  'Family (biology)': Family (biology) (id: ??, ns: 0),
#  'Feodossija': Feodossija (id: ??, ns: 0),
#  'Ferdinand I, Holy Roman Emperor': Ferdinand I, Holy Roman Emperor (id: ??, ns: 0),
#  'Five pillars of Islam': Five pillars of Islam (id: ??, ns: 0),
#  'Flora of China': Flora of China (id: ??, ns: 0),
#  'Flora of North America': Flora of North America (id: ??, ns: 0),
#  'Floristry': Floristry (id: ??, ns: 0),
#  'Flowering plant': Flowering plant (id: ??, ns: 0),
#  'Flowers': Flowers (id: ??, ns: 0),
#  'French language': French language (id: ??, ns: 0),
#  'Fritillaria': Fritillaria (id: ??, ns: 0),
#  'Fritillaria imperialis': Fritillaria imperialis (id: ??, ns: 0),
#  'Fruit': Fruit (id: ??, ns: 0),
#  'Fungal disease': Fungal disease (id: ??, ns: 0),
#  'Gagea': Gagea (id: ??, ns: 0),
#  'Gauze': Gauze (id: ??, ns: 0),
#  'Gene': Gene (id: ??, ns: 0),
#  'Genus': Genus (id: ??, ns: 0),
#  'Geophytes': Geophytes (id: ??, ns: 0),
#  'Germplasm Resources Information Network': Germplasm Resources Information Network (id: ??, ns: 0),
#  'Glabrousness (botany)': Glabrousness (botany) (id: ??, ns: 0),
#  'Global Biodiversity Information Facility': Global Biodiversity Information Facility (id: ??, ns: 0),
#  'Globose': Globose (id: ??, ns: 0),
#  'Glossary of botanical terms': Glossary of botanical terms (id: ??, ns: 0),
#  'Greece': Greece (id: ??, ns: 0),
#  'Green peach aphid': Green peach aphid (id: ??, ns: 0),
#  'Greenhouse': Greenhouse (id: ??, ns: 0),
#  "Gulistan of Sa'di": Gulistan of Sa'di (id: ??, ns: 0),
#  'Gynoecium': Gynoecium (id: ??, ns: 0),
#  'Haarlem': Haarlem (id: ??, ns: 0),
#  'Hajji': Hajji (id: ??, ns: 0),
#  'Herat': Herat (id: ??, ns: 0),
#  'Herbaceous': Herbaceous (id: ??, ns: 0),
#  'Hermaphrodite': Hermaphrodite (id: ??, ns: 0),
#  'Himalayas': Himalayas (id: ??, ns: 0),
#  'Holland, Michigan': Holland, Michigan (id: ??, ns: 0),
#  'Horticulture': Horticulture (id: ??, ns: 0),
#  'Hortus Botanicus Leiden': Hortus Botanicus Leiden (id: ??, ns: 0),
#  'Houghton Mifflin': Houghton Mifflin (id: ??, ns: 0),
#  'Husayn Bayqarah': Husayn Bayqarah (id: ??, ns: 0),
#  'Hyacinth (plant)': Hyacinth (plant) (id: ??, ns: 0),
#  'Hybrid (biology)': Hybrid (biology) (id: ??, ns: 0),
#  'INaturalist': INaturalist (id: ??, ns: 0),
#  'ISBN (identifier)': ISBN (identifier) (id: ??, ns: 0),
#  'Iberian peninsula': Iberian peninsula (id: ??, ns: 0),
#  'Integrated Taxonomic Information System': Integrated Taxonomic Information System (id: ??, ns: 0),
#  'Interim Register of Marine and Nonmarine Genera': Interim Register of Marine and Nonmarine Genera (id: ??, ns: 0),
#  'International Plant Names Index': International Plant Names Index (id: ??, ns: 0),
#  'Internet Archive': Internet Archive (id: ??, ns: 0),
#  'Introduced species': Introduced species (id: ??, ns: 0),
#  'Introrse': Introrse (id: ??, ns: 0),
#  'Iowa': Iowa (id: ??, ns: 0),
#  'Iran': Iran (id: ??, ns: 0),
#  'Iranian Green Movement': Iranian Green Movement (id: ??, ns: 0),
#  'Iranian flag': Iranian flag (id: ??, ns: 0),
#  'Iranian government': Iranian government (id: ??, ns: 0),
#  'Iran–Iraq War': Iran–Iraq War (id: ??, ns: 0),
#  'Istanbul': Istanbul (id: ??, ns: 0),
#  'JSTOR (identifier)': JSTOR (identifier) (id: ??, ns: 0),
#  'Jerevan': Jerevan (id: ??, ns: 0),
#  'Keukenhof': Keukenhof (id: ??, ns: 0),
#  'Kew Publishing': Kew Publishing (id: ??, ns: 0),
#  'Kosovo': Kosovo (id: ??, ns: 0),
#  'Laleh Park': Laleh Park (id: ??, ns: 0),
#  'Latitude': Latitude (id: ??, ns: 0),
#  'Leaves': Leaves (id: ??, ns: 0),
#  'Leiden University': Leiden University (id: ??, ns: 0),
#  'Lettuce': Lettuce (id: ??, ns: 0),
#  'Levant': Levant (id: ??, ns: 0),
#  'Liliaceae': Liliaceae (id: ??, ns: 0),
#  'Liliales': Liliales (id: ??, ns: 0),
#  'Lilieae': Lilieae (id: ??, ns: 0),
#  'Lilioideae': Lilioideae (id: ??, ns: 0),
#  'Lilium': Lilium (id: ??, ns: 0),
#  'Lisse': Lisse (id: ??, ns: 0),
#  'List of Award of Garden Merit tulips': List of Award of Garden Merit tulips (id: ??, ns: 0),
#  'List of edible flowers': List of edible flowers (id: ??, ns: 0),
#  'Lotus flower': Lotus flower (id: ??, ns: 0),
#  'Lynn, Massachusetts': Lynn, Massachusetts (id: ??, ns: 0),
#  'Maarten Christenhusz': Maarten Christenhusz (id: ??, ns: 0),
#  'Mahmoud Ahmadinejad': Mahmoud Ahmadinejad (id: ??, ns: 0),
#  'Major Arcana': Major Arcana (id: ??, ns: 0),
#  'Manisa': Manisa (id: ??, ns: 0),
#  'Mark Chase': Mark Chase (id: ??, ns: 0),
#  'Martyr': Martyr (id: ??, ns: 0),
#  'Massachusetts': Massachusetts (id: ??, ns: 0),
#  'Meadow': Meadow (id: ??, ns: 0),
#  'Medeola virginiana': Medeola virginiana (id: ??, ns: 0),
#  'Medeoleae': Medeoleae (id: ??, ns: 0),
#  'Mediterranean vegetation': Mediterranean vegetation (id: ??, ns: 0),
#  'Merosity': Merosity (id: ??, ns: 0),
#  'Michael Pollan': Michael Pollan (id: ??, ns: 0),
#  'Michigan': Michigan (id: ??, ns: 0),
#  'Micropropagation': Micropropagation (id: ??, ns: 0),
#  'Molecular phylogenetics': Molecular phylogenetics (id: ??, ns: 0),
#  'Monocots': Monocots (id: ??, ns: 0),
#  'Monocotyledon': Monocotyledon (id: ??, ns: 0),
#  'Monophyletic': Monophyletic (id: ??, ns: 0),
#  'Morges': Morges (id: ??, ns: 0),
#  'Mosaic virus': Mosaic virus (id: ??, ns: 0),
#  'Mosque': Mosque (id: ??, ns: 0),
#  'Motif (visual arts)': Motif (visual arts) (id: ??, ns: 0),
#  'Mountainous': Mountainous (id: ??, ns: 0),
#  'Mughal Empire': Mughal Empire (id: ??, ns: 0),
#  'Muslin': Muslin (id: ??, ns: 0),
#  'Name of Iran': Name of Iran (id: ??, ns: 0),
#  'Narcissus (plant)': Narcissus (plant) (id: ??, ns: 0),
#  'Nardostachys jatamansi': Nardostachys jatamansi (id: ??, ns: 0),
#  'National Biodiversity Network': National Biodiversity Network (id: ??, ns: 0),
#  'National Center for Biotechnology Information': National Center for Biotechnology Information (id: ??, ns: 0),
#  'National Plant Collection': National Plant Collection (id: ??, ns: 0),
#  'National symbol': National symbol (id: ??, ns: 0),
#  'Natural Resources Conservation Service': Natural Resources Conservation Service (id: ??, ns: 0),
#  'Naturalisation (biology)': Naturalisation (biology) (id: ??, ns: 0),
#  'Near East': Near East (id: ??, ns: 0),
#  'Nectaries': Nectaries (id: ??, ns: 0),
#  'Nematode': Nematode (id: ??, ns: 0),
#  'Netherlands': Netherlands (id: ??, ns: 0),
#  'Nomocharis': Nomocharis (id: ??, ns: 0),
#  'North Africa': North Africa (id: ??, ns: 0),
#  'North America': North America (id: ??, ns: 0),
#  'North Macedonia': North Macedonia (id: ??, ns: 0),
#  'Notholirion': Notholirion (id: ??, ns: 0),
#  'Nowruz': Nowruz (id: ??, ns: 0),
#  'Offset (botany)': Offset (botany) (id: ??, ns: 0),
#  'Oghier Ghislain de Busbecq': Oghier Ghislain de Busbecq (id: ??, ns: 0),
#  'Ogier Ghiselin de Busbecq': Ogier Ghiselin de Busbecq (id: ??, ns: 0),
#  'Omar Kayam': Omar Kayam (id: ??, ns: 0),
#  'Ontario': Ontario (id: ??, ns: 0),
#  'Orange City, Iowa': Orange City, Iowa (id: ??, ns: 0),
#  'Orion Publishing Group': Orion Publishing Group (id: ??, ns: 0),
#  'Ornamental garden plants': Ornamental garden plants (id: ??, ns: 0),
#  'Oswald Wirth': Oswald Wirth (id: ??, ns: 0),
#  'Ottawa': Ottawa (id: ??, ns: 0),
#  'Ottoman Empire': Ottoman Empire (id: ??, ns: 0),
#  'Ottoman Turkish language': Ottoman Turkish language (id: ??, ns: 0),
#  'Ottoman dynasty': Ottoman dynasty (id: ??, ns: 0),
#  'Ovary (plants)': Ovary (plants) (id: ??, ns: 0),
#  'PMID (identifier)': PMID (identifier) (id: ??, ns: 0),
#  'Palestinian Territories': Palestinian Territories (id: ??, ns: 0),
#  'Pamir-Alai': Pamir-Alai (id: ??, ns: 0),
#  'Paradise': Paradise (id: ??, ns: 0),
#  'Pella, Iowa': Pella, Iowa (id: ??, ns: 0),
#  'Pendulous': Pendulous (id: ??, ns: 0),
#  'Perennial': Perennial (id: ??, ns: 0),
#  'Perianth': Perianth (id: ??, ns: 0),
#  'Perigonium': Perigonium (id: ??, ns: 0),
#  'Persian language': Persian language (id: ??, ns: 0),
#  'Petal': Petal (id: ??, ns: 0),
#  'Petals': Petals (id: ??, ns: 0),
#  'Peter Hadland Davis': Peter Hadland Davis (id: ??, ns: 0),
#  'Pietro Andrea Mattioli': Pietro Andrea Mattioli (id: ??, ns: 0),
#  'Plant': Plant (id: ??, ns: 0),
#  'Plant Heritage': Plant Heritage (id: ??, ns: 0),
#  'Plant morphology': Plant morphology (id: ??, ns: 0),
#  'Plant stem': Plant stem (id: ??, ns: 0),
#  'Plant tissue culture': Plant tissue culture (id: ??, ns: 0),
#  'Plants of the World Online': Plants of the World Online (id: ??, ns: 0),
#  'Pluriflor': Pluriflor (id: ??, ns: 0),
#  'Postage stamp': Postage stamp (id: ??, ns: 0),
#  'Prosartes': Prosartes (id: ??, ns: 0),
#  'Qasim (Afghan scholar)': Qasim (Afghan scholar) (id: ??, ns: 0),
#  'Rafael Govaerts': Rafael Govaerts (id: ??, ns: 0),
#  'Rembrandt': Rembrandt (id: ??, ns: 0),
#  'Romania': Romania (id: ??, ns: 0),
#  'Romeo and Juliet': Romeo and Juliet (id: ??, ns: 0),
#  'Royal Botanic Gardens, Kew': Royal Botanic Gardens, Kew (id: ??, ns: 0),
#  'Royal Horticultural Society': Royal Horticultural Society (id: ??, ns: 0),
#  'Rumi': Rumi (id: ??, ns: 0),
#  'Russia': Russia (id: ??, ns: 0),
#  'S2CID (identifier)': S2CID (identifier) (id: ??, ns: 0),
#  "Sa'di (poet)": Sa'di (poet) (id: ??, ns: 0),
#  'Saffron': Saffron (id: ??, ns: 0),
#  'Salem, Massachusetts': Salem, Massachusetts (id: ??, ns: 0),
#  'Samarkand': Samarkand (id: ??, ns: 0),
#  'Scape (botany)': Scape (botany) (id: ??, ns: 0),
#  'Sclerotium rolfsii': Sclerotium rolfsii (id: ??, ns: 0),
#  'Scoliopus': Scoliopus (id: ??, ns: 0),
#  'Seed': Seed (id: ??, ns: 0),
#  'Seeds': Seeds (id: ??, ns: 0),
#  'Selim II': Selim II (id: ??, ns: 0),
#  'Seljuks': Seljuks (id: ??, ns: 0),
#  'Sepals': Sepals (id: ??, ns: 0),
#  'Serbia': Serbia (id: ??, ns: 0),
#  "Shi'ite Islam": Shi'ite Islam (id: ??, ns: 0),
#  'Siberia': Siberia (id: ??, ns: 0),
#  'Simin Behbahani': Simin Behbahani (id: ??, ns: 0),
#  'Sinai Peninsula': Sinai Peninsula (id: ??, ns: 0),
#  'Skagit Valley': Skagit Valley (id: ??, ns: 0),
#  'Skagit Valley Tulip Festival': Skagit Valley Tulip Festival (id: ??, ns: 0),
#  'Southern Hemisphere': Southern Hemisphere (id: ??, ns: 0),
#  'Spalding, Lincolnshire': Spalding, Lincolnshire (id: ??, ns: 0),
#  'Species': Species (id: ??, ns: 0),
#  'Species Plantarum': Species Plantarum (id: ??, ns: 0),
#  'Speculation': Speculation (id: ??, ns: 0),
#  'Spil Dağı': Spil Dağı (id: ??, ns: 0),
#  'Spring (season)': Spring (season) (id: ??, ns: 0),
#  'Spring Pond': Spring Pond (id: ??, ns: 0),
#  'Stachybotrys': Stachybotrys (id: ??, ns: 0),
#  'Stained glass': Stained glass (id: ??, ns: 0),
#  'Stamen': Stamen (id: ??, ns: 0),
#  'Steppes': Steppes (id: ??, ns: 0),
#  'Sterility (physiology)': Sterility (physiology) (id: ??, ns: 0),
#  'Stigma (botany)': Stigma (botany) (id: ??, ns: 0),
#  'Streptopoideae': Streptopoideae (id: ??, ns: 0),
#  'Streptopus': Streptopus (id: ??, ns: 0),
#  'Subgenera': Subgenera (id: ??, ns: 0),
#  'Subspecies': Subspecies (id: ??, ns: 0),
#  'Suleyman the Magnificent': Suleyman the Magnificent (id: ??, ns: 0),
#  'Swabia': Swabia (id: ??, ns: 0),
#  'Sword': Sword (id: ??, ns: 0),
#  'Sydenham Edwards': Sydenham Edwards (id: ??, ns: 0),
#  'Symbol': Symbol (id: ??, ns: 0),
#  'Synonym (taxonomy)': Synonym (taxonomy) (id: ??, ns: 0),
#  'Tarot cards': Tarot cards (id: ??, ns: 0),
#  'Tashkent': Tashkent (id: ??, ns: 0),
#  'Taxonomy (biology)': Taxonomy (biology) (id: ??, ns: 0),
#  'Taxonomy of Tulipa': Taxonomy of Tulipa (id: ??, ns: 0),
#  'Temperate climate': Temperate climate (id: ??, ns: 0),
#  'Temperate climates': Temperate climates (id: ??, ns: 0),
#  'Temperate grasslands, savannas, and shrublands': Temperate grasslands, savannas, and shrublands (id: ??, ns: 0),
#  'Tepal': Tepal (id: ??, ns: 0),
#  'Tepals': Tepals (id: ??, ns: 0),
#  'The Black Tulip': The Black Tulip (id: ??, ns: 0),
#  'The New York Times': The New York Times (id: ??, ns: 0),
#  'Tien-Shan': Tien-Shan (id: ??, ns: 0),
#  'Timber Press': Timber Press (id: ??, ns: 0),
#  'Tomb': Tomb (id: ??, ns: 0),
#  'Topkapı Palace': Topkapı Palace (id: ??, ns: 0),
#  'Topping (agriculture)': Topping (agriculture) (id: ??, ns: 0),
#  'Tribe (biology)': Tribe (biology) (id: ??, ns: 0),
#  'Trichoderma viride': Trichoderma viride (id: ??, ns: 0),
#  'Tricyrtis': Tricyrtis (id: ??, ns: 0),
#  'Tropicos': Tropicos (id: ??, ns: 0),
#  'Tulip (disambiguation)': Tulip (disambiguation) (id: ??, ns: 0),
#  'Tulip Time Festival': Tulip Time Festival (id: ??, ns: 0),
#  'Tulip breaking virus': Tulip breaking virus (id: ??, ns: 0),
#  'Tulip era': Tulip era (id: ??, ns: 0),
#  'Tulip festival': Tulip festival (id: ??, ns: 0),
#  'Tulip mania': Tulip mania (id: ??, ns: 0),
#  'Tulip period': Tulip period (id: ??, ns: 0),
#  'Tulipa': Tulipa (id: ??, ns: 0),
#  'Tulipa clusiana': Tulipa clusiana (id: ??, ns: 0),
#  'Tulipa gesneriana': Tulipa gesneriana (id: ??, ns: 0),
#  'Tulipa orphanidea': Tulipa orphanidea (id: ??, ns: 0),
#  'Tulipa schrenkii': Tulipa schrenkii (id: ??, ns: 0),
#  'Tulipa sylvestris': Tulipa sylvestris (id: ??, ns: 0),
#  'Tulipa turkestanica': Tulipa turkestanica (id: ??, ns: 0),
#  'Tulipa ×gesneriana': Tulipa ×gesneriana (id: ??, ns: 0),
#  'Tulipanin': Tulipanin (id: ??, ns: 0),
#  'Tulipiere': Tulipiere (id: ??, ns: 0),
#  'Tunica (biology)': Tunica (biology) (id: ??, ns: 0),
#  'Turban': Turban (id: ??, ns: 0),
#  'Turkey': Turkey (id: ??, ns: 0),
#  'Turkic languages': Turkic languages (id: ??, ns: 0),
#  'Turkish Airlines': Turkish Airlines (id: ??, ns: 0),
#  'Turkish language': Turkish language (id: ??, ns: 0),
#  'Turkmenistan': Turkmenistan (id: ??, ns: 0),
#  'Type species': Type species (id: ??, ns: 0),
#  'Ukraine': Ukraine (id: ??, ns: 0),
#  'United States': United States (id: ??, ns: 0),
#  'Variegation': Variegation (id: ??, ns: 0),
#  'Vascular plant': Vascular plant (id: ??, ns: 0),
#  'Vernalization': Vernalization (id: ??, ns: 0),
#  'Washington (U.S. state)': Washington (U.S. state) (id: ??, ns: 0),
#  'Whorl (botany)': Whorl (botany) (id: ??, ns: 0),
#  'Wikidata': Wikidata (id: ??, ns: 0),
#  'Wikispecies': Wikispecies (id: ??, ns: 0),
#  'World Checklist of Selected Plant Families': World Checklist of Selected Plant Families (id: ??, ns: 0),
#  'World Flora Online': World Flora Online (id: ??, ns: 0),
#  'Zinaida Botschantzeva': Zinaida Botschantzeva (id: ??, ns: 0),
#  'Wikipedia:Citation needed': Wikipedia:Citation needed (id: ??, ns: 4),
#  'Wikipedia:Please clarify': Wikipedia:Please clarify (id: ??, ns: 4),
#  'Template:Cite journal': Template:Cite journal (id: ??, ns: 10),
#  'Template:Liliaceae': Template:Liliaceae (id: ??, ns: 10),
#  'Template:Taxonomy/Tulipa': Template:Taxonomy/Tulipa (id: ??, ns: 10),
#  'Template talk:Liliaceae': Template talk:Liliaceae (id: ??, ns: 11),
#  'Help:Authority control': Help:Authority control (id: ??, ns: 12),
#  'Help:Taxon identifiers': Help:Taxon identifiers (id: ??, ns: 12),
#  'Category:Articles with BNF identifiers': Category:Articles with BNF identifiers (id: ??, ns: 14),
#  'Category:Articles with GND identifiers': Category:Articles with GND identifiers (id: ??, ns: 14),
#  'Category:Articles with J9U identifiers': Category:Articles with J9U identifiers (id: ??, ns: 14),
#  'Category:Articles with LCCN identifiers': Category:Articles with LCCN identifiers (id: ??, ns: 14),
#  'Category:Articles with LNB identifiers': Category:Articles with LNB identifiers (id: ??, ns: 14),
#  'Category:Articles with NDL identifiers': Category:Articles with NDL identifiers (id: ??, ns: 14),
#  'Category:Articles with NKC identifiers': Category:Articles with NKC identifiers (id: ??, ns: 14),
#  'Category:Articles with unsourced statements from April 2019': Category:Articles with unsourced statements from April 2019 (id: ??, ns: 14),
#  'Category:Articles with unsourced statements from February 2016': Category:Articles with unsourced statements from February 2016 (id: ??, ns: 14),
#  'Category:Articles with unsourced statements from January 2021': Category:Articles with unsourced statements from January 2021 (id: ??, ns: 14),
#  'Category:Articles with unsourced statements from March 2016': Category:Articles with unsourced statements from March 2016 (id: ??, ns: 14),
#  'Category:CS1 maint: DOI inactive as of February 2022': Category:CS1 maint: DOI inactive as of February 2022 (id: ??, ns: 14),
#  'Category:Use British English from January 2021': Category:Use British English from January 2021 (id: ??, ns: 14),
#  'Category:Use dmy dates from January 2021': Category:Use dmy dates from January 2021 (id: ??, ns: 14),
#  'Category:Wikipedia articles needing clarification from January 2014': Category:Wikipedia articles needing clarification from January 2014 (id: ??, ns: 14)}

# %%
import wikipediaapi
wiki_wiki = wikipediaapi.Wikipedia('en')
# page = wiki_wiki.page('Bellis perennis')
page = wiki_wiki.page('tulips')
print(page.exists())
print(page)
print(page.summary)
# Out:
# True
# Tulip (id: 19595060, ns: 0)
# Tulips (Tulipa) are a genus of spring-blooming perennial herbaceous bulbiferous geophytes (having bulbs as storage organs). The flowers are usually large, showy and brightly coloured, generally red, pink, yellow, or white (usually in warm colours). They often have a different coloured blotch at the base of the tepals (petals and sepals, collectively), internally. Because of a degree of variability within the populations, and a long history of cultivation, classification has been complex and controversial. The tulip is a member of the lily family, Liliaceae, along with 14 other genera, where it is most closely related to Amana, Erythronium and Gagea in the tribe Lilieae.
# There are about 75 species, and these are divided among four subgenera. The name "tulip" is thought to be derived from a Persian word for turban, which it may have been thought to resemble by those who discovered it. Tulips originally were found in a band stretching from Southern Europe to Central Asia, but since the seventeenth century have become widely naturalised and cultivated (see map). In their natural state they are adapted to steppes and mountainous areas with temperate climates. Flowering in the spring, they become dormant in the summer once the flowers and leaves die back, emerging above ground as a shoot from the underground bulb in early spring.
# Growing wild over much of the Near East and Central Asia, tulips were cultivated in Constantinople as early as 1055. By the 15th century, tulips were among the most prized flowers; becoming the symbol of the Ottomans. While tulips had probably been cultivated in Persia from the tenth century, they did not come to the attention of the West until the sixteenth century, when Western diplomats to the Ottoman court observed and reported on them.  They were rapidly introduced into Europe and became a frenzied commodity during tulip mania. Tulips were frequently depicted in Dutch Golden Age paintings, and have become associated with the Netherlands, the major producer for world markets, ever since. In the seventeenth century Netherlands, during the time of the tulip mania, an infection of tulip bulbs by the tulip breaking virus created variegated patterns in the tulip flowers that were much admired and valued. While truly broken tulips do not exist anymore, the closest available specimens today are part of the group known as the Rembrandts – so named because Rembrandt painted some of the most admired breaks of his time.Breeding programmes have produced thousands of hybrid and cultivars in addition to the original species (known in horticulture as botanical tulips).  They are popular throughout the world, both as ornamental garden plants and as cut flowers.

# %%
def wikipedia_summary(predicted_flower):
    wiki_wiki = wikipediaapi.Wikipedia('en')
    # page = wiki_wiki.page('Bellis perennis')
    if predicted_flower == 'daisy':
        page = wiki_wiki.page('Bellis perennis')
        summary = page.summary

    elif predicted_flower == 'roses':
        page = wiki_wiki.page('roses')
        summary = page.summary       
    
    elif predicted_flower == 'sunflowers':
        page = wiki_wiki.page('sunflowers')
        summary = page.summary 

    elif predicted_flower == 'tulips':
        page = wiki_wiki.page('tulips')
        summary = page.summary

    return summary

# %%
wikipedia_summary('tulips')
# Out:
#   Input In [21]
#     and
#     ^
# SyntaxError: invalid syntax
